# %%
print (3.134332 * 6345.123)
# Out:
# 19887.722062836

# %%
import matplotlib.pyplot as plt

plt.style.use("dark_background")

plt.figure(figsize=(10,8))
plt.plot([1.0,2.0,5.0], [1.0,6.0,9.0])
plt.xlabel("time")
plt.ylabel("displacement")
# Out:
# Text(0, 0.5, 'displacement')
